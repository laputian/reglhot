# %%
from model import test_run

# %% [markdown]
# Illustrates how the price jump frequency distribution my change radically depending on the stock price/liquidity ratio in the market.

# %%
# %matplotlib inline

# %%
test_run()
# Out:
# Init: 20 investors, initial price = 85.0
# Tot assets 110345.0
# Tot cash 27300.0
# Final
# Tot assets 149100.290628
# Tot cash 27300.0

# %%
test_run(init_price=125.)
# Out:
# Init: 20 investors, initial price = 125.0
# Tot assets 149425.0
# Tot cash 27300.0
# Final
# Tot assets 147847.647558
# Tot cash 27300.0
