# %% [markdown]
# #### Illustrating the impact of panic-selling triggered by liquidity shortages.

# %%
from model import test_run

# %%
# %matplotlib inline

# %%
test_run()
# Out:
# Init: 20 investors, initial price = 125.0
# Tot assets 149425.0
# Tot cash 27300.0
# Final
# Tot assets 147847.647558
# Tot cash 27300.0

# %%
test_run(num_sell_fail = 2)
# Out:
# Init: 20 investors, initial price = 125.0
# Tot assets 149425.0
# Tot cash 27300.0
# Final
# Tot assets 88371.4727999
# Tot cash 27300.0
